# %%
# Load dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:,.1e}'.format
import sys
pd.options.display.float_format = '{:,.1e}'.format
sys.path.insert(0,'../../../statistics_helper/')
# from excel_utils import *

# %% [markdown]
# # Estimating the biomass of livestock
# To estimate the biomass of livestock, we rely on data on global stocks of cattle, sheep goats, and pigs froms the Food and Agriculture Organization database FAOStat. We downloaded data from the domain Production/Live animals.
# We combined data on the total stocks of each animal with estimates of the mean mass of each type of animal species (in kg) from [Dong et al.](http://www.ipcc-nggip.iges.or.jp/public/2006gl/pdf/4_Volume4/V4_10_Ch10_Livestock.pdf), Annex 10A.2, Tables 10A-4 to 10A-9.
#
# Here are samples of the data:

# %%
# Load global stocks data
stocks = pd.read_csv('FAOSTAT_stock_data_mammals.csv')
stocks.head()
# Out:
#   Domain Code        Domain  Area Code    Area  Element Code Element  \
# 0          QA  Live Animals       5100  Africa          5111  Stocks
# 1          QA  Live Animals       5100  Africa          5111  Stocks
# 2          QA  Live Animals       5100  Africa          5111  Stocks
# 3          QA  Live Animals       5100  Africa          5111  Stocks
# 4          QA  Live Animals       5100  Africa          5111  Stocks
#
#    Item Code       Item  Year Code  Year  Unit      Value Flag  \
# 0       1107      Asses       2014  2014  Head   18946358    A
# 1        946  Buffaloes       2014  2014  Head    3949287    A
# 2       1126     Camels       2014  2014  Head   23533724    A
# 3        866     Cattle       2014  2014  Head  312327289    A
# 4       1016      Goats       2014  2014  Head  374380445    A
#
#                                     Flag Description
# 0  Aggregate, may include official, semi-official...
# 1  Aggregate, may include official, semi-official...
# 2  Aggregate, may include official, semi-official...
# 3  Aggregate, may include official, semi-official...
# 4  Aggregate, may include official, semi-official...

# %%
# Load species body mass data
body_mass = pd.read_excel('livestock_body_mass.xlsx',skiprows=1,index_col=0) 
body_mass
# Out:
#                      Cattle - dairy  Cattle - non-dairy  Buffaloes  \
# IPCC Area
# Indian Subcontinent             275                 110        295
# Eastern Europe                  550                 391        380
# Africa                          275                 173        380
# Oceania                         500                 330        380
# Western Europe                  600                 420        380
# Latin America                   400                 305        380
# Asia                            350                 391        380
# Middle east                     275                 173        380
# Northern America                604                 389        380
#
#                      Swine - market  Swine - breeding  Sheep  Goats  Horses  \
# IPCC Area
# Indian Subcontinent              28                28 28.000 30.000     238
# Eastern Europe                   50               180 48.500 38.500     377
# Africa                           28                28 28.000 30.000     238
# Oceania                          45               180 48.500 38.500     377
# Western Europe                   50               198 48.500 38.500     377
# Latin America                    28                28 28.000 30.000     238
# Asia                             50               180 48.500 38.500     377
# Middle east                      28                28 28.000 30.000     238
# Northern America                 46               198 48.500 38.500     377
#
#                      Asses  Mules  Camels  Camelids, other
# IPCC Area
# Indian Subcontinent    130    130     217              217
# Eastern Europe         130    130     217              217
# Africa                 130    130     217              217
# Oceania                130    130     217              217
# Western Europe         130    130     217              217
# Latin America          130    130     217              217
# Asia                   130    130     217              217
# Middle east            130    130     217              217
# Northern America       130    130     217              217

# %% [markdown]
# We pivot the stocks DataFrame to have a view of each kind of animal at each region:

# %%
# Replace NaN with zeros
stocks.fillna(value=0,inplace=True)
stock_pivot = pd.pivot(stocks, index='Area', columns='Item', values='Value').astype(float)

# Replace NaN with zeros
stock_pivot.fillna(value=0,inplace=True)

stock_pivot
# Out:
# Item               Asses  Buffaloes  Camelids, other  Camels  Cattle   Goats  \
# Area
# Africa           1.9e+07    3.9e+06          0.0e+00 2.4e+07 3.1e+08 3.7e+08
# Americas         6.8e+06    1.3e+06          8.9e+06 0.0e+00 5.1e+08 3.6e+07
# Asia             1.6e+07    1.9e+08          0.0e+00 4.2e+06 4.9e+08 5.8e+08
# Eastern Europe   1.0e+05    1.7e+04          0.0e+00 7.4e+03 4.0e+07 4.6e+06
# Northern America 5.2e+04    0.0e+00          0.0e+00 0.0e+00 1.0e+08 2.6e+06
# Oceania          9.0e+03    2.4e+02          0.0e+00 0.0e+00 4.0e+07 4.0e+06
# Southern Asia    8.3e+06    1.5e+08          0.0e+00 1.7e+06 2.7e+08 2.9e+08
# Western Europe   3.4e+04    6.5e+03          0.0e+00 0.0e+00 4.2e+07 2.1e+06
#
# Item              Horses   Mules    Pigs   Sheep
# Area
# Africa           6.1e+06 1.0e+06 3.4e+07 3.4e+08
# Americas         3.3e+07 5.9e+06 1.7e+08 8.6e+07
# Asia             1.4e+07 3.0e+06 5.9e+08 5.4e+08
# Eastern Europe   2.8e+06 3.5e+03 5.3e+07 3.6e+07
# Northern America 1.1e+07 4.0e+03 8.1e+07 6.1e+06
# Oceania          4.0e+05 0.0e+00 5.3e+06 1.0e+08
# Southern Asia    1.3e+06 5.8e+05 1.1e+07 1.5e+08
# Western Europe   1.1e+06 3.1e+04 6.5e+07 1.1e+07

# %% [markdown]
# There is a difference between the body mass of a dairy producing cow to a non-dairy producing cow. We thus count seperately the dairy producing cattle from the non-dairy producing cattle. Data about the amount of dairy cattle comes from the FAOStat domain Production - Livestock Primary.
# There is also a difference in body mass between breeding and non-breeding pigs. We assume 90% of the population is breeding based on IPCC, 2006, Vol.4, Ch.10,Table.10.19.

# %%
# Load data on the number of dairy producing cattle
dairy = pd.read_csv('FAOSTAT_cattle_dairy_data.csv')

# Set the index of the DataFrame to be the region so we can compare with the stocks data
dairy.set_index('Area',inplace=True)

# Add a category of dairy producing cattle
stock_pivot['Cattle - dairy'] = dairy.Value

# Set the amount of non-dairy producing cattle to be the total number minus the dairy producing cattle
stock_pivot['Cattle'] = stock_pivot['Cattle']-stock_pivot['Cattle - dairy']

# Rename the Cattle column name to Cattle - non-dairy
stock_pivot.rename(columns={'Cattle': 'Cattle - non-dairy'}, inplace=True)

# Set the amount of non-breeding (market) pigs (swine) to 10% of the total amount of pigs
stock_pivot['Swine - market'] = 0.1*stock_pivot['Pigs']

# Set the amount of breeding pigs (swine) to 90% of the total amount of pigs
stock_pivot['Pigs'] *= 0.9

# Rename the Pigs column name to Swine - breeding
stock_pivot.rename(columns={'Pigs': 'Swine - breeding'}, inplace=True)

stock_pivot
# Out:
# Item               Asses  Buffaloes  Camelids, other  Camels  \
# Area
# Africa           1.9e+07    3.9e+06          0.0e+00 2.4e+07
# Americas         6.8e+06    1.3e+06          8.9e+06 0.0e+00
# Asia             1.6e+07    1.9e+08          0.0e+00 4.2e+06
# Eastern Europe   1.0e+05    1.7e+04          0.0e+00 7.4e+03
# Northern America 5.2e+04    0.0e+00          0.0e+00 0.0e+00
# Oceania          9.0e+03    2.4e+02          0.0e+00 0.0e+00
# Southern Asia    8.3e+06    1.5e+08          0.0e+00 1.7e+06
# Western Europe   3.4e+04    6.5e+03          0.0e+00 0.0e+00
#
# Item              Cattle - non-dairy   Goats  Horses   Mules  \
# Area
# Africa                       2.4e+08 3.7e+08 6.1e+06 1.0e+06
# Americas                     4.5e+08 3.6e+07 3.3e+07 5.9e+06
# Asia                         3.8e+08 5.8e+08 1.4e+07 3.0e+06
# Eastern Europe               2.3e+07 4.6e+06 2.8e+06 3.5e+03
# Northern America             9.1e+07 2.6e+06 1.1e+07 4.0e+03
# Oceania                      3.3e+07 4.0e+06 4.0e+05 0.0e+00
# Southern Asia                2.0e+08 2.9e+08 1.3e+06 5.8e+05
# Western Europe               3.1e+07 2.1e+06 1.1e+06 3.1e+04
#
# Item              Swine - breeding   Sheep  Cattle - dairy  Swine - market
# Area
# Africa                     3.1e+07 3.4e+08        67436568         3.4e+06
# Americas                   1.5e+08 8.6e+07        54930519         1.7e+07
# Asia                       5.3e+08 5.4e+08       107571193         5.9e+07
# Eastern Europe             4.8e+07 3.6e+07        16188776         5.3e+06
# Northern America           7.3e+07 6.1e+06        10161310         8.1e+06
# Oceania                    4.8e+06 1.0e+08         6874751         5.3e+05
# Southern Asia              1.0e+07 1.5e+08        69325063         1.1e+06
# Western Europe             5.8e+07 1.1e+07        11289409         6.5e+06

# %% [markdown]
# Data on the mass of animals is divided into different regions than the FAOStat data so we need preprocess the stocks DataFrame and merge it with the body mass data:

# %%
# Preprocessing the stocks DataFrame

# Calculate the total number of animals in Latin America by subtracting values for Northern America from the total
# values for the Americas
stock_pivot.loc['Americas'] -= stock_pivot.loc['Northern America']

# Change name of Americas to Latin America
stock_pivot.rename(index={'Americas': 'Latin America'},inplace=True)

# Calculate the total number of animals in Asia without the Indian Subcontinent by subtracting values for the Southern Asia 
# from the total values for the Asia
stock_pivot.loc['Asia'] -= stock_pivot.loc['Southern Asia']

# Change name of Southern Asia to Indian Subcontinent
stock_pivot.rename(index={'Southern Asia': 'Indian Subcontinent'},inplace=True)


stock_pivot
# Out:
# Item                  Asses  Buffaloes  Camelids, other  Camels  \
# Area
# Africa              1.9e+07    3.9e+06          0.0e+00 2.4e+07
# Latin America       6.7e+06    1.3e+06          8.9e+06 0.0e+00
# Asia                8.2e+06    3.7e+07          0.0e+00 2.5e+06
# Eastern Europe      1.0e+05    1.7e+04          0.0e+00 7.4e+03
# Northern America    5.2e+04    0.0e+00          0.0e+00 0.0e+00
# Oceania             9.0e+03    2.4e+02          0.0e+00 0.0e+00
# Indian Subcontinent 8.3e+06    1.5e+08          0.0e+00 1.7e+06
# Western Europe      3.4e+04    6.5e+03          0.0e+00 0.0e+00
#
# Item                 Cattle - non-dairy   Goats  Horses   Mules  \
# Area
# Africa                          2.4e+08 3.7e+08 6.1e+06 1.0e+06
# Latin America                   3.6e+08 3.3e+07 2.2e+07 5.9e+06
# Asia                            1.8e+08 2.9e+08 1.3e+07 2.4e+06
# Eastern Europe                  2.3e+07 4.6e+06 2.8e+06 3.5e+03
# Northern America                9.1e+07 2.6e+06 1.1e+07 4.0e+03
# Oceania                         3.3e+07 4.0e+06 4.0e+05 0.0e+00
# Indian Subcontinent             2.0e+08 2.9e+08 1.3e+06 5.8e+05
# Western Europe                  3.1e+07 2.1e+06 1.1e+06 3.1e+04
#
# Item                 Swine - breeding   Sheep  Cattle - dairy  Swine - market
# Area
# Africa                        3.1e+07 3.4e+08        67436568         3.4e+06
# Latin America                 8.0e+07 8.0e+07        44769209         8.9e+06
# Asia                          5.2e+08 3.8e+08        38246130         5.8e+07
# Eastern Europe                4.8e+07 3.6e+07        16188776         5.3e+06
# Northern America              7.3e+07 6.1e+06        10161310         8.1e+06
# Oceania                       4.8e+06 1.0e+08         6874751         5.3e+05
# Indian Subcontinent           1.0e+07 1.5e+08        69325063         1.1e+06
# Western Europe                5.8e+07 1.1e+07        11289409         6.5e+06

# %% [markdown]
# We now multiply the stocks of each animal type and for each region by the characteristic body weight of each animal:

# %%
wet_biomass =(body_mass*stock_pivot)
wet_biomass
# Out:
#                       Asses  Buffaloes  Camelids, other  Camels  \
# Africa              2.5e+09    1.5e+09          0.0e+00 5.1e+09
# Asia                1.1e+09    1.4e+10          0.0e+00 5.5e+08
# Eastern Europe      1.3e+07    6.3e+06          0.0e+00 1.6e+06
# Indian Subcontinent 1.1e+09    4.5e+10          0.0e+00 3.7e+08
# Latin America       8.8e+08    5.0e+08          1.9e+09 0.0e+00
# Middle east             NaN        NaN              NaN     NaN
# Northern America    6.8e+06    0.0e+00          0.0e+00 0.0e+00
# Oceania             1.2e+06    9.3e+04          0.0e+00 0.0e+00
# Western Europe      4.4e+06    2.5e+06          0.0e+00 0.0e+00
#
#                      Cattle - dairy  Cattle - non-dairy   Goats  Horses  \
# Africa                      1.9e+10             4.2e+10 1.1e+10 1.4e+09
# Asia                        1.3e+10             7.2e+10 1.1e+10 4.9e+09
# Eastern Europe              8.9e+09             9.2e+09 1.8e+08 1.0e+09
# Indian Subcontinent         1.9e+10             2.2e+10 8.8e+09 3.2e+08
# Latin America               1.8e+10             1.1e+11 9.9e+08 5.2e+09
# Middle east                     NaN                 NaN     NaN     NaN
# Northern America            6.1e+09             3.5e+10 1.0e+08 4.0e+09
# Oceania                     3.4e+09             1.1e+10 1.5e+08 1.5e+08
# Western Europe              6.8e+09             1.3e+10 7.9e+07 4.1e+08
#
#                       Mules   Sheep  Swine - breeding  Swine - market
# Africa              1.3e+08 9.5e+09           8.7e+08         9.6e+07
# Asia                3.1e+08 1.9e+10           9.4e+10         2.9e+09
# Eastern Europe      4.6e+05 1.8e+09           8.6e+09         2.6e+08
# Indian Subcontinent 7.6e+07 4.3e+09           2.9e+08         3.2e+07
# Latin America       7.7e+08 2.2e+09           2.2e+09         2.5e+08
# Middle east             NaN     NaN               NaN             NaN
# Northern America    5.2e+05 3.0e+08           1.4e+10         3.7e+08
# Oceania             0.0e+00 5.0e+09           8.7e+08         2.4e+07
# Western Europe      4.1e+06 5.2e+08           1.2e+10         3.2e+08

# %% [markdown]
# @kian Here we also calculate the mass of manure generated by each livestock category. To do so, we extrapolate from the human value of 100 g/d (estimated from daily experience), and argue that waste production across species should scale with food intake, which scales with Kleiber's Law.

# %%
def kleiber_scaling(m):
    # given an animal's mass, return its metabolic scaling relative to man
    avg_human_mass = 62 # kg
    return (m/avg_human_mass)**0.75

# %% [markdown]
# First, we use this to find the metabolic scaling of each species relative to humans:

# %%
# find the metabolic scaling of each animal relative to man
kleiber = body_mass.applymap(kleiber_scaling)
kleiber
# Out:
#                      Cattle - dairy  Cattle - non-dairy  Buffaloes  \
# IPCC Area
# Indian Subcontinent           3.056               1.537      3.222
# Eastern Europe                5.140               3.980      3.895
# Africa                        3.056               2.159      3.895
# Oceania                       4.786               3.504      3.895
# Western Europe                5.487               4.199      3.895
# Latin America                 4.048               3.303      3.895
# Asia                          3.662               3.980      3.895
# Middle east                   3.056               2.159      3.895
# Northern America              5.514               3.964      3.895
#
#                      Swine - market  Swine - breeding  Sheep  Goats  Horses  \
# IPCC Area
# Indian Subcontinent           0.551             0.551  0.551  0.580   2.742
# Eastern Europe                0.851             2.224  0.832  0.700   3.872
# Africa                        0.551             0.551  0.551  0.580   2.742
# Oceania                       0.786             2.224  0.832  0.700   3.872
# Western Europe                0.851             2.389  0.832  0.700   3.872
# Latin America                 0.551             0.551  0.551  0.580   2.742
# Asia                          0.851             2.224  0.832  0.700   3.872
# Middle east                   0.551             0.551  0.551  0.580   2.742
# Northern America              0.799             2.389  0.832  0.700   3.872
#
#                      Asses  Mules  Camels  Camelids, other
# IPCC Area
# Indian Subcontinent  1.742  1.742   2.559            2.559
# Eastern Europe       1.742  1.742   2.559            2.559
# Africa               1.742  1.742   2.559            2.559
# Oceania              1.742  1.742   2.559            2.559
# Western Europe       1.742  1.742   2.559            2.559
# Latin America        1.742  1.742   2.559            2.559
# Asia                 1.742  1.742   2.559            2.559
# Middle east          1.742  1.742   2.559            2.559
# Northern America     1.742  1.742   2.559            2.559

# %% [markdown]
# Then we use these values to predict their annual solid waste production (in kg/yr):

# %%
# calculate the expected manure production of each animal (on an individual basis)
# from a human baseline of 36.5 kg/yr
manure = kleiber.applymap(lambda x: x*36.5)  # kg/yr

# scale by population size
pop_manure = (stock_pivot*manure)
pop_manure
# Out:
#                                 Asses          Buffaloes  Camelids, other  \
# Africa              1,204,986,970.171    561,507,408.175            0.000
# Asia                  520,832,324.670  5,283,784,473.488            0.000
# Eastern Europe          6,582,019.960      2,361,316.115            0.000
# Indian Subcontinent   527,942,987.216 17,829,960,831.718            0.000
# Latin America         429,276,351.339    188,600,314.286  830,706,978.764
# Middle east                       NaN                NaN              NaN
# Northern America        3,307,577.761              0.000            0.000
# Oceania                   572,399.336         34,833.962            0.000
# Western Europe          2,167,676.284        925,161.606            0.000
#
#                                Camels    Cattle - dairy  Cattle - non-dairy  \
# Africa              2,198,034,746.822 7,523,052,241.498  19,297,720,169.521
# Asia                  234,599,763.845 5,112,550,695.798  26,660,677,891.452
# Eastern Europe            693,490.244 3,037,282,083.697   3,402,723,875.053
# Indian Subcontinent   157,191,121.936 7,733,727,947.041  11,216,753,858.176
# Latin America                   0.000 6,614,903,485.222  43,816,740,281.093
# Middle east                       NaN               NaN                 NaN
# Northern America                0.000 2,045,156,290.241  13,107,489,807.988
# Oceania                         0.000 1,200,835,652.302   4,265,785,099.992
# Western Europe                  0.000 2,260,912,434.342   4,739,014,492.918
#
#                                 Goats            Horses           Mules  \
# Africa              7,927,809,294.617   606,415,754.113  65,068,257.675
# Asia                7,340,201,573.742 1,836,439,596.303 151,171,491.335
# Eastern Europe        117,285,244.098   390,070,075.287     223,108.541
# Indian Subcontinent 6,209,159,352.416   132,491,769.914  37,110,556.926
# Latin America         698,792,783.525 2,185,397,441.260 377,381,673.573
# Middle east                       NaN               NaN             NaN
# Northern America       67,440,471.352 1,507,943,018.820     254,463.305
# Oceania               101,949,791.309    57,208,312.186           0.000
# Western Europe         52,370,199.904   155,364,708.465   1,999,899.679
#
#                                  Sheep   Swine - breeding    Swine - market
# Africa               6,851,763,433.458    621,312,377.868    69,034,708.652
# Asia                11,625,992,831.778 42,320,733,269.049 1,799,218,048.005
# Eastern Europe       1,106,925,663.342  3,867,915,789.966   164,440,059.515
# Indian Subcontinent  3,082,869,897.867    204,670,632.670    22,741,181.408
# Latin America        1,607,317,474.285  1,611,916,472.261   179,101,830.251
# Middle east                        NaN                NaN               NaN
# Northern America       186,410,441.827  6,343,417,364.909   235,857,808.189
# Oceania              3,109,861,299.506    390,569,397.828    15,343,014.985
# Western Europe         327,901,278.699  5,092,785,249.734   201,577,226.079

# %%
# hence the total waste production worldwide is
total_manure = pop_manure.sum().sum()/1e12 # Gt/yr

print(total_manure)

# and since 1% of this fresh weight is phosphorus,
P_content = 0.001 * total_manure

print(P_content)
# Out:
# 0.3130786206445035
# 0.0003130786206445035

# %% [markdown]
# Thus we find that the world's livestock produce about 3 x 10^11 kg of manure every year, which corresponds to roughly 3 x 10^8 kg of phosphorus.
#
# _Note._ The 1% fresh weight calculation is a very rough first approximation. Actual nutrient composition of manure varies widely with species, diet, geography, etc. [One source](https://extension.okstate.edu/fact-sheets/managing-phosphorus-from-animal-manure.html) suggests around 30 lb of P2O5 per (likely short) ton of manure, i.e. 30 lb / 2000 lb = 0.015x P2O5 = 0.006x P, or 6%. This would mean:

# %%
0.006 * total_manure
# Out:
# 0.0018784717238670208

# %% [markdown]
# or about 2 x 10^9 kg P/yr. Another American [source](https://extension.umn.edu/manure-management/manure-characteristics#graph-summary-2317710) (but a much more well-annotated one) differentiates between solid and liquid waste storage for different species, suggesting an average value between 0.002x P2O5 and 0.006x P205 (say 0.004x), = 2% P.
#
# So our first value may be a slight underestimate, but I feel confident declaring that the phosphorus content of the world's manure is perhaps 5 x 10^8 kg P/yr.

# %% [markdown]
# We sum over all regions and convert units from kg wet weight to Gt C carbon by assuming carbon is ≈15% of the wet weight (30% dry weight of wet weight and carbon is 50% of dry weight).

# %%
pd.options.display.float_format = '{:,.3f}'.format

# conversion factor from kg wet weight to Gt C
kg_to_gt_c = 1000*0.15/1e15
total_biomass = wet_biomass.sum()*kg_to_gt_c
total_biomass
# Out:
# Asses                0.001
# Buffaloes            0.009
# Camelids, other      0.000
# Camels               0.001
# Cattle - dairy       0.014
# Cattle - non-dairy   0.047
# Goats                0.005
# Horses               0.003
# Mules                0.000
# Sheep                0.006
# Swine - breeding     0.020
# Swine - market       0.001
# dtype: float64

# %% [markdown]
# We sum over all animal categories to generate our best estimate for the total biomass of livestock

# %%
best_estimate = total_biomass.sum()
print('Our best estimate for the biomass of mammal livestock is %.1f Gt C' % best_estimate)
# Out:
# Our best estimate for the biomass of mammal livestock is 0.1 Gt C

# %%
# Feed results to the chordate biomass data
old_results = pd.read_excel('../../animal_biomass_estimate.xlsx',index_col=0)
result = old_results.copy()
result.loc['Livestock',(['Biomass [Gt C]','Uncertainty'])] = (best_estimate,None)
result.to_excel('../../animal_biomass_estimate.xlsx')

# Feed results to Table 1 & Fig. 1
update_results(sheet='Table1 & Fig1', 
               row=('Animals','Livestock'), 
               col='Biomass [Gt C]',
               values=best_estimate,
               path='../../../results.xlsx')

# Feed results to Table S1
update_results(sheet='Table S1', 
               row=('Animals','Livestock'), 
               col='Number of individuals',
               values=stock_pivot.sum().sum(),
               path='../../../results.xlsx')
